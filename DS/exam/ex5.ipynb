# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.neighbors import KNeighborsClassifier

# %%
iris = load_iris()
x = iris.data
y = iris.target

print(iris.feature_names)
print(iris.target_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# ['setosa' 'versicolor' 'virginica']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3)

# %%
model = KNeighborsClassifier(n_neighbors=5)
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = model.predict(x_test)

# %%
print("Accuracy: ", accuracy_score(y_test, y_pred))
print("Confusion matrix: \n",confusion_matrix(y_test, y_pred))
print("Classification report: \n",classification_report(y_test, y_pred, target_names=iris.target_names))
# Out:
# Accuracy:  0.9777777777777777
# Confusion matrix:
#  [[11  0  0]
#  [ 0 19  0]
#  [ 0  1 14]]
# Classification report:
#                precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        11
#   versicolor       0.95      1.00      0.97        19
#    virginica       1.00      0.93      0.97        15
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %%
plt.figure(figsize=[10,8])
plt.scatter(x_test[:,0],x_test[:,1], c=y_test, ec="k")
plt.title("KNeighborsClassifier")
plt.xlabel("Sepal length")
plt.ylabel("Sepal width")
plt.legend()
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_22428\2985273607.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
sample = [[2,2,2,2]]
pred = model.predict(sample)[0]
print(iris.target_names[pred])
# Out:
# setosa
