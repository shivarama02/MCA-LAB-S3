# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
diabetes = load_diabetes()
x = diabetes.data[:, 2].reshape(-1,1)
y = diabetes.target

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
print("Coefficient: ",model.coef_)
print("Intercept: ",model.intercept_)
print("mean squared error: ",round(mean_squared_error(y_test,y_pred),2))
print("R^2 score: ",round(r2_score(y_test,y_pred),2))
# Out:
# Coefficient:  [921.08333064]
# Intercept:  150.29897416293497
# mean squared error:  3460.66
# R^2 score:  0.37

# %%
plt.figure(figsize=(10,6))
plt.scatter(x_test, y_test, color="black", label="Actual")
sortt = np.argsort(x_test[:,0])
plt.plot(x_test[sortt],y_pred[sortt], color="blue",linewidth=2, label="Predicted")
plt.title("LinearRegression: BMI vs Diabetes Progression")
plt.xlabel("BMI")
plt.ylabel("diabetes Progression")
plt.legend()
plt.show()
