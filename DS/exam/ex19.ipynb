# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.linear_model import  LinearRegression

# %%
diabetes = load_diabetes()
x = diabetes.data[:, [0,2]]
y = diabetes.target

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
print("Coefficient: ",model.coef_)
print("Intercept: ",model.intercept_)
print("mean squared error: ",round(mean_squared_error(y_test,y_pred),2))
print("R^2 score: ",round(r2_score(y_test,y_pred),2))
# Out:
# Coefficient:  [182.57260211 963.7421    ]
# Intercept:  154.09683220938481
# mean squared error:  4281.38
# R^2 score:  0.29

# %%
plt.figure(figsize=[20,6])
plt.subplot(1,2,1)
plt.scatter(x_test[:, 0], y_test, color='red')
plt.scatter(x_test[:, 0], y_pred, color='blue')
plt.xlabel('Feature 0 (Age)')
plt.ylabel('Diabetes Progression')
plt.title('Feature 0 vs Target')

plt.subplot(1,2,2)
plt.scatter(x_test[:, 1], y_test, color='orange')
plt.scatter(x_test[:, 1], y_pred, color='green')
plt.xlabel('Feature 0 (BMI)')
plt.ylabel('Diabetes Progression')
plt.title('Feature 0 vs Target')

plt.show()
