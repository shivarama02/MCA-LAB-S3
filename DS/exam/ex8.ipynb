# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score, normalized_mutual_info_score

# %%
iris = load_iris()
x = iris.data
y = iris.target

# %%
model = KMeans(n_clusters=3)
model.fit(x)
labels = model.labels_

# %%
plt.figure(figsize=[10,8])
plt.subplot(1,2,1)
plt.scatter(x[:,0],x[:,1], c=y, cmap="prism", ec="k")
plt.title("Actual")
plt.xlabel("Sepal length")
plt.ylabel("Sepal width")

plt.subplot(1,2,2)
plt.scatter(x[:,0],x[:,1], c=labels, cmap="jet", ec="k")
plt.title("Predicted")
plt.xlabel("Sepal length")
plt.ylabel("Sepal width")
plt.show()

# %%
print("ARI: ",adjusted_rand_score(y, labels))
print("NMI: ",normalized_mutual_info_score(y, labels))
# Out:
# ARI:  0.7302382722834697
# NMI:  0.7581756800057784
